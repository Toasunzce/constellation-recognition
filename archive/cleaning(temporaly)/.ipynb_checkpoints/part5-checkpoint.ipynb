# %%
import pandas as pd
import numpy as np
import scipy
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../naked_df.csv')
df = df.sort_values(by=['con'])
df = df.set_index(['con', 'hip'])
df
# Out:
#                   id        hd  hr   gl   bf proper         ra        dec  \
# con hip
# And 114642.0  114280       NaN NaN  NaN  NaN    NaN  23.224074  35.762021
#     9194.0      9175   11951.0 NaN  NaN  NaN    NaN   1.972931  43.621980
#     3251.0      3244    3858.0 NaN  NaN  NaN    NaN   0.690387  28.042635
#     117691.0  117323       NaN NaN  NaN  NaN    NaN  23.868756  37.850250
#     115461.0  115096       NaN NaN  NaN  NaN    NaN  23.388891  43.101533
# ...              ...       ...  ..  ...  ...    ...        ...        ...
# Vul 97057.0    96750  344787.0 NaN  NaN  NaN    NaN  19.724830  23.177959
#     100983.0  100657  334488.0 NaN  NaN  NaN    NaN  20.474322  28.954089
#     101743.0  101416  346992.0 NaN  NaN  NaN    NaN  20.621383  23.895299
#     98386.0    98075  333327.0 NaN  NaN  NaN    NaN  19.990121  28.241549
#     102331.0  102000  197573.0 NaN  NaN  NaN    NaN  20.733344  21.400658
#
#                      dist    mag  spect bayer  flam           lum
# ...

# %%
# 'Com', 'CVn', 'Boo', 'Cir', 'Aps', 'Lup', 'Lib', 'TrA', 'Ser',
# 'Nor', 'CrB', 'Sco', 'Her', 'Oph', 'Ara', 'Pav', 'Sgr', 'CrA',

# %%
# ===================================== 1
# Com = Coma Berenecies (волосы Вероники)

# %%
Com = df.xs('Com', level='con')
Com = Com.loc[[60742, 64394, 64241]]
Com['con'] = 'Com'

# %%
Com.sort_values(by='bayer')
# Out:
#             id        hd      hr       gl         bf  proper         ra  \
# hip
# 64241.0  64037  114378.0  4968.0  Gl 501A  42Alp Com  Diadem  13.166469
# 64394.0  64189  114710.0  4983.0   Gl 502  43Bet Com     NaN  13.197904
# 60742.0  60554  108381.0  4737.0      NaN  15Gam Com     NaN  12.448966
#
#                dec     dist   mag        spect bayer  flam        lum  con
# hip
# 64241.0  17.529431  17.8253  4.32          F5V   Alp  42.0   5.176068  Com
# 64394.0  27.878183   9.1291  4.23          G0V   Bet  43.0   1.475027  Com
# 60742.0  28.268423  51.2821  4.35  K2IIICN+...   Gam  15.0  41.686938  Com

# %%
Com_con = ((60742, 64394), (64394, 64241))

# %%
# ===================================== 2
# CVn = Canes Venatici (гончие псы)

# %%
CVn = df.xs('CVn', level='con')
CVn = CVn.loc[[61317, 63125]]
CVn['con'] = 'CVn'

# %%
CVn.sort_values(by='bayer')
# Out:
#             id        hd      hr      gl         bf      proper         ra  \
# hip
# 63125.0  62925  112413.0  4915.0     NaN  12Alp2CVn  Cor Caroli  12.933807
# 61317.0  61124  109358.0  4785.0  Gl 475   8Bet CVn       Chara  12.562411
#
#               dec     dist   mag     spect  bayer  flam        lum  con
# hip
# 63125.0  38.31838  35.1989  2.89  A0spe...  Alp-2  12.0  75.370258  CVn
# 61317.0  41.35748   8.4395  4.24       G0V    Bet   8.0   1.249683  CVn

# %%
CVn_con = ((61317, 63125))

# %%
# ===================================== 3
# Boo = Bootes (волопас)

# %%
Boo = df.xs('Boo', level='con')
Boo = Boo.loc[[67459, 67927, 69673, 71053, 71075, 73555, 74666, 72105, 71795]]
Boo['con'] = 'Boo'

# %%
Boo.sort_values(by='bayer')
# Out:
#             id        hd      hr      gl         bf    proper         ra  \
# hip
# 69673.0  69451  124897.0  5340.0  Gl 541  16Alp Boo  Arcturus  14.261030
# 73555.0  73327  133208.0  5602.0     NaN  42Bet Boo    Nekkar  15.032436
# 74666.0  74438  135722.0  5681.0     NaN  49Del Boo       NaN  15.258376
# 72105.0  71879  129988.0  5505.0     NaN  36Eps Boo      Izar  14.749784
# 67927.0  67711  121370.0  5235.0  Gl 534   8Eta Boo   Muphrid  13.911411
# 71075.0  70851  127762.0  5435.0     NaN  27Gam Boo   Seginus  14.534636
# 71053.0  70828  127665.0  5429.0     NaN  25Rho Boo       NaN  14.530500
# 67459.0  67246  120477.0  5200.0     NaN   5Ups Boo       NaN  13.824623
# 71795.0  71569  129246.0  5477.0     NaN  30Zet Boo       NaN  14.685820
#
#                dec     dist   mag     spect bayer  flam         lum  con
# hip
# 69673.0  19.182410  11.2575 -0.05    K2IIIp   Alp  16.0  115.557996  Boo
# 73555.0  40.390566  69.0608  3.49     G8III   Bet  42.0  166.878351  Boo
# ...

# %%
Boo_con = ((67459, 67927), (67927, 69673), (69673, 71053), (71053, 71075), (71075, 73555), (73555, 74666), (74666, 72105), (72105, 69673), (69673, 71795))

# %%
# ===================================== 4
# Cir = Circinus (циркуль)

# %%
Cir = df.xs('Cir', level='con')
Cir = Cir.loc[[74824, 71908, 75323]]
Cir['con'] = 'Cir'

# %%
Cir.sort_values(by='bayer')
# Out:
#             id        hd      hr        gl       bf proper         ra  \
# hip
# 71908.0  71682  128898.0  5463.0   Gl 560A  Alp Cir    NaN  14.708492
# 74824.0  74595  135379.0  5670.0  Gl 580.1  Bet Cir    NaN  15.291917
# 75323.0  75094  136415.0  5704.0       NaN  Gam Cir    NaN  15.389625
#
#                dec      dist   mag       spect bayer  flam         lum  con
# hip
# 71908.0 -64.975138   16.5700  3.18        F1Vp   Alp   NaN   12.787923  Cir
# 74824.0 -58.801208   30.5530  4.07         A3V   Bet   NaN   19.142559  Cir
# 75323.0 -59.320787  137.5516  4.48  B5III + F8   Gam   NaN  265.950003  Cir

# %%
Cir_con = ((74824, 71908), (71908, 75323))

# %%
# ===================================== 5 
# Aps = Apus (райская птица)

# %%
Aps = df.xs('Aps', level='con')
Aps = Aps.loc[[72370, 81065, 81852]]
Aps['con'] = 'Aps'

# %%
Aps.sort_values(by='bayer')
# Out:
#             id        hd      hr        gl       bf proper         ra  \
# hip
# 72370.0  72144  129078.0  5470.0       NaN  Alp Aps    NaN  14.797701
# 81852.0  81602  149324.0  6163.0       NaN  Bet Aps    NaN  16.718126
# 81065.0  80819  147675.0  6102.0  Gl 626.1  Gam Aps    NaN  16.557609
#
#                dec      dist   mag    spect bayer  flam         lum  con
# hip
# 72370.0 -79.044751  136.9863  3.83    K5III   Alp   NaN  479.954425  Aps
# 81852.0 -77.517435   48.1232  4.23    K0III   Bet   NaN   41.001524  Aps
# 81065.0 -78.897148   47.9157  3.86  K0IV SB   Gam   NaN   57.121552  Aps

# %%
Aps_con = ((72370, 81065), (81065, 81852))

# %%
# ===================================== 6
# Lup = Lupus (волк)

# %%
Lup = df.xs('Lup', level='con')
Lup = Lup.loc[[71860, 73273, 75141, 76297, 76552, 74395, 77634, 78384, 78970, 75177, 70576, 71536]]
Lup['con'] = 'Lup'

# %%
Lup.sort_values(by='bayer')
# Out:
#             id        hd      hr        gl        bf proper         ra  \
# hip
# 71860.0  71634  129056.0  5469.0       NaN   Alp Lup    NaN  14.698823
# 73273.0  73046  132058.0  5571.0       NaN   Bet Lup    NaN  14.975537
# 77634.0  77398  141556.0  5883.0       NaN  5Chi Lup    NaN  15.849316
# 75141.0  74912  136298.0  5695.0       NaN   Del Lup    NaN  15.356201
# 78384.0  78148  143118.0  5948.0       NaN   Eta Lup    NaN  16.002036
# 76297.0  76065  138690.0  5776.0       NaN   Gam Lup    NaN  15.585681
# 76552.0  76317  139127.0  5797.0       NaN   Ome Lup    NaN  15.634232
# 75177.0  74948  136422.0  5705.0       NaN   Phi1Lup    NaN  15.363440
# 71536.0  71310  128345.0  5453.0       NaN   Rho Lup    NaN  14.631454
# 70576.0  70353  126354.0  5396.0       NaN   Tau2Lup    NaN  14.436336
# 74395.0  74167  134505.0  5649.0  GJ 9512A   Zet Lup    NaN  15.204760
# 78970.0  78730  144415.0  5991.0       NaN       NaN    NaN  16.121168
#
# ...

# %%
Lup_con = ((71860, 73273), (73273, 75141), (75141, 76297), (76297, 76552), (76552, 74395), (74395, 71860),
           (77634, 78384), (78384, 78970), (78970, 77634), (78384, 76297), (75177, 75141), (70576, 71860), (71536, 74395))

# %%
# ===================================== 7
# Lib = Libra (весы)

# %%
Lib = df.xs('Lib', level='con')
Lib = Lib.loc[[73714, 72622, 74785, 76333, 77853]]
Lib['con'] = 'Lib'

# %%
Lib.sort_values(by='bayer')
# Out:
#             id        hd      hr        gl         bf          proper  \
# hip
# 72622.0  72396  130841.0  5531.0  Gl 564.1   9Alp2Lib   Zubenelgenubi
# 74785.0  74556  135742.0  5685.0       NaN  27Bet Lib  Zubeneschamali
# 76333.0  76100  138905.0  5787.0   GJ 3912  38Gam Lib  Zubenelhakrabi
# 73714.0  73486  133216.0  5603.0       NaN  20Sig Lib        Brachium
# 77853.0  77617  142198.0  5908.0       NaN  46The Lib             NaN
#
#                 ra        dec     dist   mag     spect  bayer  flam  \
# hip
# 72622.0  14.847977 -16.041778  23.2396  2.75      A3IV  Alp-2   9.0
# 74785.0  15.283449  -9.382917  56.7537  2.61       B8V    Bet  27.0
# 76333.0  15.592105 -14.789537  50.0250  3.91     K0III    Gam  38.0
# 73714.0  15.067839 -25.281965  88.4173  3.25  M3/M4III    Sig  20.0
# 77853.0  15.897093 -16.729293  51.6529  4.13     K0III    The  46.0
#
#                 lum  con
# hip
# 72622.0   37.359409  Lib
# 74785.0  253.512863  Lib
# 76333.0   59.483977  Lib
# ...

# %%
Lib_con = ((73714, 72622), (72622, 74785), (74785, 76333), (76333, 77853), (73714, 76333))

# %%
# ===================================== 8
# TrA = Triangulum Australe (южный треугольник)

# %%
TrA = df.xs('TrA', level='con')
TrA = TrA.loc[[82273, 74946, 77952]]
TrA['con'] = 'TrA'

# %%
TrA.sort_values(by='bayer')
# Out:
#             id        hd      hr       gl       bf proper         ra  \
# hip
# 82273.0  82022  150798.0  6217.0      NaN  Alp TrA  Atria  16.811077
# 77952.0  77716  141891.0  5897.0  Gl 601A  Bet TrA    NaN  15.919083
# 74946.0  74717  135382.0  5671.0      NaN  Gam TrA    NaN  15.315181
#
#                dec      dist   mag       spect bayer  flam          lum  con
# hip
# 82273.0 -69.027715  119.7605  1.91  K2IIb-IIIa   Alp   NaN  2151.790570  TrA
# 77952.0 -63.430727   12.3778  2.83       F2III   Bet   NaN     9.844644  TrA
# 74946.0 -68.679545   56.3698  2.87         A1V   Gam   NaN   196.788629  TrA

# %%
TrA_con = ((82273, 74946), (74946, 77952), (77952, 82273))

# %%
# ===================================== 9
# Ser = Serpens (змея)

# %%
Ser = df.xs('Ser', level='con')
Ser = Ser.loc[[77516, 77622, 77070, 76276, 77233, 77450, 78072]]
Ser['con'] = 'Ser'

# %%
Ser.sort_values(by='bayer')
# Out:
#             id        hd      hr        gl         bf     proper         ra  \
# hip
# 77070.0  76835  140573.0  5854.0  Gl 596.2  24Alp Ser  Unukalhai  15.737798
# 77233.0  76997  141003.0  5867.0       NaN  28Bet Ser        NaN  15.769793
# 76276.0  76044  138917.0  5788.0       NaN  13Del Ser        NaN  15.580041
# 77622.0  77386  141795.0  5892.0   GJ 3921  37Eps Ser        NaN  15.846935
# 78072.0  77836  142860.0  5933.0    Gl 603  41Gam Ser        NaN  15.940882
# 77450.0  77214  141477.0  5879.0       NaN  35Kap Ser      Gudja  15.812327
# 77516.0  77280  141513.0  5881.0       NaN  32Mu  Ser        NaN  15.827002
#
#                dec      dist   mag  spect bayer  flam         lum  con
# hip
# 77070.0   6.425627   22.6757  2.63  K2III   Alp  24.0   39.737451  Ser
# 77233.0  15.421826   47.5511  3.65    A3V   Bet  28.0   68.296744  Ser
# 76276.0  10.538867   69.9301  3.80   F0IV   Del  13.0  128.587869  Ser
# ...

# %%
Ser_con = ((77516, 77622), (77622, 77070), (77070, 76276), (76276, 77233), (77233, 77450), (77450, 78072), (78072, 77233))

# %%
# ===================================== 10
# Nor = Norma (наугольник)

# %%
Nor = df.xs('Nor', level='con')
Nor = Nor.loc[[80582, 78639, 79509, 80000]]
Nor['con'] = 'Nor'

# %%
Nor.sort_values(by='bayer')
# Out:
#             id        hd      hr       gl       bf proper         ra  \
# hip
# 80582.0  80339  147971.0  6115.0      NaN  Eps Nor    NaN  16.453067
# 78639.0  78400  143546.0  5962.0      NaN  Eta Nor    NaN  16.053579
# 80000.0  79759  146686.0  6072.0  GJ 9554  Gam2Nor    NaN  16.330687
# 79509.0  79270  145397.0  6024.0      NaN  Kap Nor    NaN  16.224648
#
#                dec      dist   mag  spect  bayer  flam         lum  con
# hip
# 80582.0 -47.554786  162.6016  4.46    B4V    Eps   NaN  378.791304  Nor
# 78639.0 -49.229695   67.2948  4.65  G8III    Eta   NaN   54.450265  Nor
# 80000.0 -50.155508   39.4789  4.01  G8III  Gam-2   NaN   33.790919  Nor
# 79509.0 -54.630467  131.2336  4.95  G4III    Kap   NaN  157.036280  Nor

# %%
Nor_con = ((80582, 78639), (78639, 79509), (79509, 80000), (80000, 80582), (80000, 78639))

# %%
# ===================================== 11
# CrB = Corona Borealis (северная корона)

# %%
CrB = df.xs('CrB', level='con')
CrB = CrB.loc[[76127, 75695, 76267, 76952, 77512, 78159, 78493]]
CrB['con'] = 'CrB'

# %%
CrB.sort_values(by='bayer')
# Out:
#             id        hd      hr   gl         bf    proper         ra  \
# hip
# 76267.0  76035  139006.0  5793.0  NaN   5Alp CrB  Alphecca  15.578128
# 75695.0  75466  137909.0  5747.0  NaN   3Bet CrB   Nusakan  15.463818
# 77512.0  77276  141714.0  5889.0  NaN  10Del CrB       NaN  15.826570
# 78159.0  77923  143107.0  5947.0  NaN  13Eps CrB       NaN  15.959794
# 76952.0  76716  140436.0  5849.0  NaN   8Gam CrB       NaN  15.712381
# 78493.0  78256  143807.0  5971.0  NaN  14Iot CrB       NaN  16.024047
# 76127.0  75895  138749.0  5778.0  NaN   4The CrB       NaN  15.548829
#
#                dec      dist   mag     spect bayer  flam         lum  con
# hip
# 76267.0  26.714693   23.0097  2.22       A0V   Alp   5.0   59.703529  CrB
# 75695.0  29.105703   34.2818  3.66       F0p   Bet   3.0   35.156044  CrB
# 77512.0  26.068394   52.1376  4.59  G5III-IV   Del  10.0   34.546177  CrB
# 78159.0  26.877880   67.8887  4.14     K3III   Eps  13.0   88.633929  CrB
# ...

# %%
CrB_con = ((76127, 75695), (75695, 76267), (76267, 76952), (76952, 77512), (77512, 78159), (78159, 78493))

# %%
# ===================================== 12
# Sco = Scorpius (скорпион)

# %%
Sco = df.xs('Sco', level='con')
Sco = Sco.loc[[85927, 86670, 87073, 86228, 84143, 82671, 82514, 82396, 81266, 80763, 78820, 78401, 78265]]
Sco['con'] = 'Sco'

# %%
Sco.sort_values(by='bayer')
# Out:
#             id        hd      hr      gl         bf      proper         ra  \
# hip
# 80763.0  80519  148478.0  6134.0     NaN  21Alp Sco     Antares  16.490128
# 78820.0  78580  144217.0  5984.0     NaN   8Bet1Sco       Acrab  16.090620
# 78401.0  78165  143275.0  5953.0     NaN   7Del Sco    Dschubba  16.005557
# 82396.0  82144  151680.0  6241.0     NaN  26Eps Sco     Larawag  16.836080
# 84143.0  83885  155203.0  6380.0  Gl 657    Eta Sco         NaN  17.202552
# 87073.0  86804  161471.0  6615.0     NaN    Iot1Sco         NaN  17.793078
# 86670.0  86403  160578.0  6580.0     NaN    Kap Sco         NaN  17.708132
# 85927.0  85665  158926.0  6527.0     NaN  35Lam Sco      Shaula  17.560145
# 82514.0  82263  151890.0  6247.0     NaN    Mu 1Sco  Xamidimura  16.864509
# 78265.0  78029  143018.0  5944.0     NaN   6Pi  Sco        Fang  15.980865
# 81266.0  81020  149438.0  6165.0     NaN  23Tau Sco  Paikauhale  16.598043
# ...

# %%
Sco_con = ((85927, 86670), (86670, 87073), (87073, 86228), (86228, 84143), (84143, 82671), (82671, 82514), (82514, 82396), (82396, 81266), (81266, 80763), (80763, 78820),
           (80763, 78401), (80763, 78265))

# %%
# ===================================== 13
# Her = Hercules (геркулес)

# %%
Her = df.xs('Her', level='con')
Her = Her.loc[[84380, 83207, 81693, 81833, 86414, 87808, 85112, 84606, 77760, 79992, 81126, 80170, 80816, 88794, 87933, 86974, 85693, 84379]]
Her['con'] = 'Her'

# %%
Her.sort_values(by='bayer')
# Out:
#             id        hd      hr        gl          bf       proper  \
# hip
# 80816.0  80571  148856.0  6148.0       NaN   27Bet Her  Kornephoros
# 77760.0  77524  142373.0  5914.0    Gl 602    1Chi Her          NaN
# 84379.0  84121  156164.0  6410.0  GJ 3995A   65Del Her        Sarin
# 83207.0  82952  153808.0  6324.0       NaN   58Eps Her          NaN
# 81833.0  81583  150997.0  6220.0       NaN   44Eta Her          NaN
# 80170.0  79928  147547.0  6095.0       NaN   20Gam Her          NaN
# 86414.0  86148  160762.0  6588.0       NaN   85Iot Her          NaN
# 85693.0  85433  158899.0  6526.0       NaN   76Lam Her       Maasym
# 86974.0  86705  161797.0  6623.0   Gl 695A   86Mu  Her          NaN
# 88794.0  88517  166014.0  6779.0       NaN  103Omi Her          NaN
# 84380.0  84122  156283.0  6418.0       NaN   67Pi  Her          NaN
# 85112.0  84853  157778.0  6484.0       NaN   75Rho Her          NaN
# 81126.0  80880  149630.0  6168.0       NaN   35Sig Her          NaN
# ...

# %%
Her_con = ((84380, 83207), (83207, 81693), (81693, 81833), (81833, 84380),
           (86414, 87808), (87808, 85112), (85112, 84606), (84606, 84380),
           (77760, 79992), (79992, 81126), (81126, 81833),
           (80170, 80816), (80816, 81693),
           (88794, 87933), (87933, 86974), (86974, 85693), (85693, 84379), (85693, 83207))

# %%
# ===================================== 14
# Oph = Ophiuchus (змееносец)

# %%
Oph = df.xs('Oph', level='con')
Oph = Oph.loc[[85755, 84012, 81377, 79882, 83000, 86032, 86742]]
Oph['con'] = 'Oph'

# %%
Oph.sort_values(by='bayer')
# Out:
#             id        hd      hr         gl         bf         proper  \
# hip
# 86032.0  85769  159561.0  6556.0     Gl 681  55Alp Oph     Rasalhague
# 86742.0  86475  161096.0  6603.0        NaN  60Bet Oph       Cebalrai
# 79882.0  79640  146791.0  6075.0    GJ 3949   2Eps Oph  Yed Posterior
# 84012.0  83755  155125.0  6378.0  Gl 656.1A  35Eta Oph          Sabik
# 83000.0  82745  153210.0  6299.0        NaN  27Kap Oph            NaN
# 81377.0  81130  149757.0  6175.0        NaN  13Zet Oph            NaN
# 85755.0  85494  158643.0  6519.0        NaN  51    Oph            NaN
#
#                 ra        dec      dist   mag     spect bayer  flam  \
# hip
# 86032.0  17.582241  12.560035   14.8965  2.08     A5III   Alp  55.0
# 86742.0  17.724543   4.567303   25.0941  2.76     K2III   Bet  60.0
# 79882.0  16.305358  -4.692511   32.6371  3.23     G8III   Eps   2.0
# 84012.0  17.172968 -15.724910   27.0929  2.43    A2.5Va   Eta  35.0
# ...

# %%
Oph_con = ((85755, 84012), (84012, 81377), (81377, 79882), (79882, 83000), (83000, 86032), (86032, 86742), (86742, 84012))

# %%
# ===================================== 15
# Ara = Ara (жертвенник)

# %%
Ara = df.xs('Ara', level='con')
Ara = Ara.loc[[85727, 82363, 83081, 85792, 88714, 85258, 85267]]
Ara['con'] = 'Ara'

# %%
Ara.sort_values(by='bayer')
# Out:
#             id        hd      hr       gl       bf proper         ra  \
# hip
# 85792.0  85530  158427.0  6510.0      NaN  Alp Ara    NaN  17.530695
# 85258.0  84999  157244.0  6461.0      NaN  Bet Ara    NaN  17.421665
# 85727.0  85467  158094.0  6500.0      NaN  Del Ara    NaN  17.518318
# 82363.0  82112  151249.0  6229.0      NaN  Eta Ara    NaN  16.829760
# 85267.0  85008  157246.0  6462.0      NaN  Gam Ara    NaN  17.423239
# 88714.0  88439  165024.0  6743.0      NaN  The Ara    NaN  18.110520
# 83081.0  82826  152786.0  6285.0  GJ 9581  Zet Ara    NaN  16.977006
#
#                dec      dist   mag    spect bayer  flam          lum  con
# hip
# 85792.0 -49.876145   81.9672  2.84    B2Vne   Alp   NaN   427.759831  Ara
# 85258.0 -55.529884  198.0198  2.84  K3Ib-II   Bet   NaN  2498.043519  Ara
# 85727.0 -60.683848   60.6796  3.60      B8V   Del   NaN   116.412603  Ara
# 82363.0 -59.041378   91.7431  3.77    K5III   Eta   NaN   227.614539  Ara
# ...

# %%
Ara_con = ((85727, 82363), (82363, 83081), (83081, 85792), (85792, 88714), (88714, 85258), (85258, 85267), (85267, 85727))

# %%
# ===================================== 16
# Pav = Pavo (павлин)

# %%
Pav = df.xs('Pav', level='con')
Pav = Pav.loc[[100751, 105858, 102395, 99240, 93015, 92609, 88866, 86929, 90098, 98495, 91792]]
Pav['con'] = 'Pav'

# %%
Pav.sort_values(by='bayer')
# Out:
#               id        hd      hr      gl       bf   proper         ra  \
# hip
# 100751.0  100425  193924.0  7790.0     NaN  Alp Pav  Peacock  20.427459
# 102395.0  102064  197051.0  7913.0     NaN  Bet Pav      NaN  20.749314
# 99240.0    98924  190248.0  7665.0  Gl 780  Del Pav      NaN  20.145157
# 98495.0    98184  188228.0  7590.0     NaN  Eps Pav      NaN  20.009845
# 86929.0    86661  160635.0  6582.0     NaN  Eta Pav      NaN  17.762221
# 105858.0  105519  203608.0  8181.0  Gl 827  Gam Pav      NaN  21.440705
# 93015.0    92723  174694.0  7107.0     NaN  Kap Pav      NaN  18.949177
# 92609.0    92319  173948.0  7074.0     NaN  Lam Pav      NaN  18.870288
# 88866.0    88589  165040.0  6745.0     NaN  Pi  Pav      NaN  18.143000
# 90098.0    89819  168339.0  6855.0     NaN  Xi  Pav      NaN  18.387117
# 91792.0    91507  171759.0  6982.0     NaN  Zet Pav      NaN  18.717260
#
#                 dec      dist   mag      spect bayer  flam          lum  con
# hip
# ...

# %%
Pav_con = ((100751, 105858), (105858, 102395), (102395, 99240), (99240, 93015), (93015, 92609), (92609, 88866), (88866, 86929),
           (90098, 88866), (90098, 92609), (100751, 99240), (98495, 91792), (98495, 99240), (91792, 93015))

# %%
# ===================================== 17
# Sgr = Sagittarius (стрелец)

# %%
Sgr = df.xs('Sgr', level='con')
Sgr = Sgr.loc[[95294, 98032, 98412, 98688, 96406, 93864, 95347, 95168, 94820, 93683, 93085, 92855, 89341, 90496, 92041, 93506, 89931, 90185, 89642, 88635, 87072]]
Sgr['con'] = 'Sgr'

# %%
Sgr.sort_values(by='bayer')
# Out:
#             id        hd      hr        gl         bf           proper  \
# hip
# 95347.0  95052  181869.0  7348.0       NaN    Alp Sgr           Rukbat
# 95294.0  94999  181623.0  7343.0       NaN    Bet2Sgr  Arkab Posterior
# 89931.0  89653  168454.0  6859.0       NaN  19Del Sgr       Kaus Media
# 90185.0  89906  169022.0  6879.0       NaN  20Eps Sgr   Kaus Australis
# 89642.0  89364  167618.0  6832.0       NaN    Eta Sgr              NaN
# 88635.0  88361  165135.0  6746.0       NaN  10Gam2Sgr           Alnasl
# 98032.0  97721  188114.0  7581.0       NaN    Iot Sgr              NaN
# 90496.0  90217  169916.0  6913.0  Gl 713.1  22Lam Sgr    Kaus Borealis
# 89341.0  89064  166937.0  6812.0       NaN  13Mu  Sgr            Polis
# 93683.0  93388  177241.0  7217.0   GJ 9641  39Omi Sgr              NaN
# 92041.0  91754  173300.0  7039.0       NaN  27Phi Sgr              NaN
# 95168.0  94873  181577.0  7340.0   GJ 4107  44Rho1Sgr              NaN
# ...

# %%
Sgr_con = ((95294, 98032), (98032, 98412), (98412, 98688), (98688, 96406), (96406, 93864), (95347, 98032),
           (95168, 94820), (94820, 93683), (93683, 93085), (93085, 92855), (89341, 90496), (90496, 92041), (92041, 93506), (93506, 93864), (92041, 92855),
           (89931, 90185), (90185, 89642), (90496, 89931), (89931, 92041), (90185, 93506), (90185, 88635), (88635, 87072))

# %%
# ===================================== 18
# CrA = Corona Australis (южная корона)

# %%
CrA = df.xs('CrA', level='con')
CrA = CrA.loc[[90887, 91875, 92989, 93174, 93825, 94114, 94160, 94005, 93542, 92953]]
CrA['con'] = 'CrA'

# %%
CrA.sort_values(by='bayer')
# Out:
#             id        hd      hr         gl       bf     proper         ra  \
# hip
# 94114.0  93819  178253.0  7254.0        NaN  Alp CrA  Meridiana  19.157869
# 94160.0  93865  178345.0  7259.0        NaN  Bet CrA        NaN  19.167154
# 94005.0  93710  177873.0  7242.0        NaN  Del CrA        NaN  19.139156
# 93174.0  92881  175813.0  7152.0        NaN  Eps CrA        NaN  18.978721
# 93825.0  93530  177474.0  7226.0  Gl 743.1A  Gam CrA        NaN  19.106971
# 91875.0  91589  172777.0  7021.0        NaN  Lam CrA        NaN  18.729706
# 93542.0  93248  176638.0  7188.0        NaN  Zet CrA        NaN  19.051907
# 90887.0  90605  170642.0  6942.0        NaN      NaN        NaN  18.539257
# 92989.0  92697  175362.0  7129.0        NaN      NaN        NaN  18.944582
# 92953.0  92661  175219.0  7122.0        NaN      NaN        NaN  18.938044
#
#                dec      dist   mag        spect bayer  flam         lum  con
# hip
# ...

# %%
CrA_con = ((90887, 91875), (91875, 92989), (92989, 93174), (93174, 93825), (93825, 94114), (94114, 94160), (94160, 94005), (94005, 93542), (93542, 92953))

# %% [raw]
# !CONCLUSION!

# %% [raw]
# !CONCLUSION!

# %% [raw]
# !CONCLUSION!

# %%
# 'Com', 'CVn', 'Boo', 'Cir', 'Aps', 'Lup', 'Lib', 'TrA', 'Ser',
# 'Nor', 'CrB', 'Sco', 'Her', 'Oph', 'Ara', 'Pav', 'Sgr', 'CrA',

# %%
part_5_df = pd.concat([Com, CVn, Boo, Cir, Aps, Lup, Lib, TrA, Ser, Nor, CrB, Sco, Her, Oph, Ara, Pav, Sgr, CrA])
part_5_df['hip'] = part_5_df.index
part_5_df.to_csv('part_5_df.csv', index=False)

# %%
Com_con = ((60742, 64394), (64394, 64241))
CVn_con = ((61317, 63125))
Boo_con = ((67459, 67927), (67927, 69673), (69673, 71053), (71053, 71075), (71075, 73555), (73555, 74666), (74666, 72105), (72105, 69673), (69673, 71795))
Cir_con = ((74824, 71908), (71908, 75323))
Aps_con = ((72370, 81065), (81065, 81852))
Lup_con = ((71860, 73273), (73273, 75141), (75141, 76297), (76297, 76552), (76552, 74395), (74395, 71860),
           (77634, 78384), (78384, 78970), (78970, 77634), (78384, 76297), (75177, 75141), (70576, 71860), (71536, 74395))
Lib_con = ((73714, 72622), (72622, 74785), (74785, 76333), (76333, 77853), (73714, 76333))
TrA_con = ((82273, 74946), (74946, 77952), (77952, 82273))
Ser_con = ((77516, 77622), (77622, 77070), (77070, 76276), (76276, 77233), (77233, 77450), (77450, 78072), (78072, 77233))
Nor_con = ((80582, 78639), (78639, 79509), (79509, 80000), (80000, 80582), (80000, 78639))
CrB_con = ((76127, 75695), (75695, 76267), (76267, 76952), (76952, 77512), (77512, 78159), (78159, 78493))
Sco_con = ((85927, 86670), (86670, 87073), (87073, 86228), (86228, 84143), (84143, 82671), (82671, 82514), (82514, 82396), (82396, 81266), (81266, 80763), (80763, 78820),
           (80763, 78401), (80763, 78265))
Her_con = ((84380, 83207), (83207, 81693), (81693, 81833), (81833, 84380),
           (86414, 87808), (87808, 85112), (85112, 84606), (84606, 84380),
           (77760, 79992), (79992, 81126), (81126, 81833),
           (80170, 80816), (80816, 81693),
           (88794, 87933), (87933, 86974), (86974, 85693), (85693, 84379), (85693, 83207))
Oph_con = ((85755, 84012), (84012, 81377), (81377, 79882), (79882, 83000), (83000, 86032), (86032, 86742), (86742, 84012))
Ara_con = ((85727, 82363), (82363, 83081), (83081, 85792), (85792, 88714), (88714, 85258), (85258, 85267), (85267, 85727))
Pav_con = ((100751, 105858), (105858, 102395), (102395, 99240), (99240, 93015), (93015, 92609), (92609, 88866), (88866, 86929),
           (90098, 88866), (90098, 92609), (100751, 99240), (98495, 91792), (98495, 99240), (91792, 93015))
Sgr_con = ((95294, 98032), (98032, 98412), (98412, 98688), (98688, 96406), (96406, 93864), (95347, 98032),
           (95168, 94820), (94820, 93683), (93683, 93085), (93085, 92855), (89341, 90496), (90496, 92041), (92041, 93506), (93506, 93864), (92041, 92855),
           (89931, 90185), (90185, 89642), (90496, 89931), (89931, 92041), (90185, 93506), (90185, 88635), (88635, 87072))
CrA_con = ((90887, 91875), (91875, 92989), (92989, 93174), (93174, 93825), (93825, 94114), (94114, 94160), (94160, 94005), (94005, 93542), (93542, 92953))
